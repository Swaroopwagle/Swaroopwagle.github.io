# %% [markdown]
# <a href="https://colab.research.google.com/github/Swaroopwagle/Swaroopwagle.github.io/blob/main/new_ai_model_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

collection =[20,30,40,50]
numpy_list = np.array(collection)
print(type(numpy_list))

# %%
import numpy as np
mat_a= np.array([
    [1,2,3],
    [2,4,6]
])
print(mat_a.ndim)
print(mat_a.shape)

mat_b=np.array([
    [
        [1,3,4,5],
        [5,6,2,3]
    ],
    [
        [5,6,7,8],
        [6,8,9,10]
    ]
])

print(mat_b.ndim)
print(mat_b.shape)
print('accessing the eleemts of 3D array')
print(mat_b[0,0,2])

# %%
import numpy as np
mat_a=np.array([[1,2,3],[1,2,3]])
mat_b=np.array(['swaroop','wagle','nishant'])
print(mat_a.dtype)
print(mat_b.dtype)

# %%
import numpy as np
data_type=[
    ('name','U10'), #this is used for the defining the head and the data type
    ('age','i4')
]

mat_a=[
    ('swaroopw',20),
    ('wagle',20),
    ('nishant',21)
]

mat_a=np.array(mat_a,dtype=data_type)
print(mat_a['age'])
print(mat_a)

# %%
import numpy as np
#this is the way of converting the array of one type into another like
mat_a=np.array([1.1,2.4,3.5,2.4])
new_arr=mat_a.astype('i')
print(mat_a)
print(new_arr)

# %%
import numpy as np
mat_a=np.array([1,2,3,4])
x=mat_a.copy()
mat_a[1]=42
print(mat_a)
print(x)
